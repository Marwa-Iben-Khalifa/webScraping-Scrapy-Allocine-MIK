# %%
import pandas as pd

df_allocine=pd.read_csv("./allocine.csv")
df_allocine
# Out:
#                       author  \
# 0          Christopher Nolan
# 1                 Wilson Yip
# 2           Steven Spielberg
# 3            Robert Zemeckis
# 4            Roberto Benigni
# ..                       ...
# 85                       NaN
# 86             Peter Jackson
# 87  Roger Allers,Rob Minkoff
# 88              Milos Forman
# 89         Christopher Nolan
#
#                                                  desc  \
# 0   \nAu lieu de subtiliser un rêve, un voleur exp...
# 1   \nFilm biographique sur la vie de Ip Man, pion...
# 2   \nAlors que les forces alliées débarquent à Om...
# 3   \nAprès être arrivé en 1955 à bord d'une DeLor...
# 4   \nEn 1938, Guido, jeune homme plein de gaieté,...
# ..                                                ...
# 85  \nCondamné à perpétuité pour le meurtre de sa ...
# 86  \nTandis que les ténèbres se répandent sur la ...
# 87  \nLe long combat de Simba le lionceau pour acc...
# 88  \nRebellion dans un hôpital psychiatrique à l'...
# ...
